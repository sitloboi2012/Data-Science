# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DataSale.csv",sep=",",header=None)

# %%
data.head()
# Out:
#                 0                                    1                    2  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                                    3         4      5  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery  21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery   0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up  18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up  15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery  19.70
#
#            6          7              8
# 0   Minh Tan  Completed  Bank Transfer
# ...

# %%
data.columns = ["Name","Address","Shop Name","Time Sale","Sale Type","Total Money","Shipper","Status","Payment Type"]

# %%
data.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                            Time Sale Sale Type  Total Money  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery        21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery         0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up        18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up        15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery        19.70
#
#      Shipper     Status   Payment Type
# ...

# %%
data["Time Sale"].head()
# Out:
# 0    Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...
# 1    Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...
# 2    Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...
# 3             Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)
# 4             Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)
# Name: Time Sale, dtype: object

# %%
data_split = data["Time Sale"].str.split(' ')

# %%
data_split.head()
# Out:
# 0    [Thu, Feb, 20, 2020, 20:27:38, GMT+1030, (Aust...
# 1    [Fri, Feb, 21, 2020, 07:06:46, GMT+0800, (Sing...
# 2    [Fri, Feb, 21, 2020, 15:00:47, GMT+0800, (Sing...
# 3     [Fri, Feb, 21, 2020, 07:00:50, GMT+1030, (ACDT)]
# 4     [Fri, Feb, 21, 2020, 21:40:09, GMT+1030, (ACDT)]
# Name: Time Sale, dtype: object

# %%
data["Date"] = data_split.str.get(2)
data["Month"] = data_split.str.get(1)
data["Year"] = data_split.str.get(3)
data["Time"] = data_split.str.get(4)

# %%
data.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                            Time Sale Sale Type  Total Money  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery        21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery         0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up        18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up        15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery        19.70
#
# ...

# %%
data_new = data.drop(["Time Sale"],axis=1)

# %%
data_NaN = data_new.dropna()
data_NaN.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
# 5           Nancy                Unit5/77 cowan street    BimBim-Athol Park
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012    BimBim-Athol Park
#
#   Sale Type  Total Money    Shipper     Status   Payment Type Date Month  \
# 0  Delivery         21.8   Minh Tan  Completed  Bank Transfer   20   Feb
# 1  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer   21   Feb
# 4  Delivery         19.7  Hoang Anh  Completed  Bank Transfer   21   Feb
# 5   Pick-up          0.0  Hoang Anh  Cancelled  Bank Transfer   21   Feb
# 6  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer   23   Feb
#
#    Year      Time
# 0  2020  20:27:38
# 1  2020  07:06:46
# ...

# %%
data_NaN = data_NaN.drop(["level_0"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-9f485942abc0> in <module>
# ----> 1 data_NaN = data_NaN.drop(["level_0"],axis=1)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
data_NaN.head()

# %%
data_NaN = data_NaN.drop(["index"],axis=1)

# %%
data_NaN.head()

# %%
status_data = pd.DataFrame()
address_split = data_new["Address"].str.split(' ')

# %%
address_split.head()

# %%
data_NaN["Time Series"] = data_NaN["Date"] + " " + data_NaN["Month"] + " " + data_NaN["Year"]

# %%
data_NaN.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
# 5           Nancy                Unit5/77 cowan street    BimBim-Athol Park
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012    BimBim-Athol Park
#
#   Sale Type  Total Money    Shipper     Status   Payment Type Date Month  \
# 0  Delivery         21.8   Minh Tan  Completed  Bank Transfer   20   Feb
# 1  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer   21   Feb
# 4  Delivery         19.7  Hoang Anh  Completed  Bank Transfer   21   Feb
# 5   Pick-up          0.0  Hoang Anh  Cancelled  Bank Transfer   21   Feb
# 6  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer   23   Feb
#
#    Year      Time
# 0  2020  20:27:38
# 1  2020  07:06:46
# ...

# %%
data_NaN = data_NaN.drop(["Date"],axis=1)
data_NaN = data_NaN.drop(["Month"],axis=1)
data_Nan = data_NaN.drop(["Year"],axis=1)

# %%
data_NaN.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
# 5           Nancy                Unit5/77 cowan street    BimBim-Athol Park
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012    BimBim-Athol Park
#
#   Sale Type  Total Money    Shipper     Status   Payment Type  Year      Time
# 0  Delivery         21.8   Minh Tan  Completed  Bank Transfer  2020  20:27:38
# 1  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  2020  07:06:46
# 4  Delivery         19.7  Hoang Anh  Completed  Bank Transfer  2020  21:40:09
# 5   Pick-up          0.0  Hoang Anh  Cancelled  Bank Transfer  2020  04:30:00
# 6  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  2020  18:00:00

# %%
data_NaN = data_NaN.drop(["Year"],axis=1)

# %%
data_NaN.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
# 5           Nancy                Unit5/77 cowan street    BimBim-Athol Park
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012    BimBim-Athol Park
#
#   Sale Type  Total Money    Shipper     Status   Payment Type      Time
# 0  Delivery         21.8   Minh Tan  Completed  Bank Transfer  20:27:38
# 1  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  07:06:46
# 4  Delivery         19.7  Hoang Anh  Completed  Bank Transfer  21:40:09
# 5   Pick-up          0.0  Hoang Anh  Cancelled  Bank Transfer  04:30:00
# 6  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  18:00:00

# %%
data_NaN["Shop Name"].str.split("-")
# Out:
# 0                         [BimBim, CBD]
# 1                         [BimBim, CBD]
# 4                [BimBim, West Croydon]
# 5                  [BimBim, Athol Park]
# 6                  [BimBim, Athol Park]
#                      ...
# 157    [Vietnamese Dessert, Pennington]
# 158                [BimBim, Pennington]
# 159                  [BimBim, Prospect]
# 161       [JC's TakeAway, Croydon Park]
# 162              [BimBim, Croydon Park]
# Name: Shop Name, Length: 142, dtype: object

# %%
data_NaN.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
# 5           Nancy                Unit5/77 cowan street    BimBim-Athol Park
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012    BimBim-Athol Park
#
#   Sale Type  Total Money    Shipper     Status   Payment Type      Time
# 0  Delivery         21.8   Minh Tan  Completed  Bank Transfer  20:27:38
# 1  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  07:06:46
# 4  Delivery         19.7  Hoang Anh  Completed  Bank Transfer  21:40:09
# 5   Pick-up          0.0  Hoang Anh  Cancelled  Bank Transfer  04:30:00
# 6  Delivery          0.0  Hoang Anh  Cancelled  Bank Transfer  18:00:00

# %%
#data_NaN["Shop Suburb"] = data_NaN["Shop Name"].str.get(1)
#data_NaN["Type Shop"] = data_NaN["Shop Name"].str.
#data_NaN = data_NaN.drop(["Shop Name"],axis=1)
data.head()
shopSplit = data["Shop Name"].str.split("-")

# %%
data_NaN["Shop Suburb"] = shopSplit.str.get(1)
data_NaN["Type Shop"] = shopSplit.str.get(0)

# %%
data_NaN
data_NaN = data_NaN.drop(["Shop Name"],axis=1)

# %%
data.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                            Time Sale Sale Type  Total Money  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery        21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery         0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up        18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up        15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery        19.70
#
# ...

# %%
data_NaN.head()
# Out:
#              Name                              Address Sale Type  Total Money  \
# 0      Phoebe Dao                      267 Hutt street  Delivery         21.8
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033  Delivery          0.0
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  Delivery         19.7
# 5           Nancy                Unit5/77 cowan street   Pick-up          0.0
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012  Delivery          0.0
#
#      Shipper     Status   Payment Type      Time   Shop Suburb Type Shop
# 0   Minh Tan  Completed  Bank Transfer  20:27:38           CBD    BimBim
# 1  Hoang Anh  Cancelled  Bank Transfer  07:06:46           CBD    BimBim
# 4  Hoang Anh  Completed  Bank Transfer  21:40:09  West Croydon    BimBim
# 5  Hoang Anh  Cancelled  Bank Transfer  04:30:00    Athol Park    BimBim
# 6  Hoang Anh  Cancelled  Bank Transfer  18:00:00    Athol Park    BimBim

# %%
data_NaN.to_csv("Data_NaN.csv",index=True)

# %%
data_saleType = data_NaN[["Name","Sale Type","Status","Shop Suburb","Type Shop"]]

# %%
data_saleType.head()
# Out:
#              Name Sale Type     Status   Shop Suburb Type Shop
# 0      Phoebe Dao  Delivery  Completed           CBD    BimBim
# 1  Tran Huy Thong  Delivery  Cancelled           CBD    BimBim
# 4         Phuong   Delivery  Completed  West Croydon    BimBim
# 5           Nancy   Pick-up  Cancelled    Athol Park    BimBim
# 6       Hari Đoàn  Delivery  Cancelled    Athol Park    BimBim

# %%
address_list = data_NaN["Address"].str.split(" ")

# %%
import re
suburb = []
for i in data_NaN["Address"]:
    x = re.findall("50..",i)
    suburb.append(x)

# %%
suburb
# Out:
# [[],
#  ['5033'],
#  ['5009'],
#  [],
#  ['5012'],
#  ['5013'],
#  [],
#  [],
#  [],
#  ['5083'],
#  [],
#  [],
#  ['5008'],
#  ['5012'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['5010'],
#  [],
#  ['5000'],
#  ['5082'],
#  ['5082'],
#  ['5082'],
#  [],
#  ['5008'],
#  ['5000'],
#  [],
#  [],
#  [],
#  ['5008'],
#  ['5010'],
#  ['5000'],
#  ['5000'],
#  ['5010'],
#  ['5010'],
#  ['5065'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['5010'],
#  ['5000'],
#  [],
#  [],
#  [],
#  [],
#  ['5000'],
#  [],
#  ['5061'],
#  [],
#  [],
#  [],
#  ['5011'],
#  ['5011'],
#  ['5000'],
#  [],
#  [],
#  [],
#  ['5034'],
#  ['5083'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['5000'],
#  [],
#  [],
#  [],
#  ['5012'],
#  ['5007'],
#  [],
#  [],
#  [],
#  ['5082'],
#  [],
#  [],
#  [],
#  ['5082'],
#  ['5010'],
#  ['5007'],
#  [],
#  ['5007'],
#  [],
#  ['5033'],
#  ['5013'],
#  ['5013'],
#  [],
#  ['5033'],
#  ['5008'],
#  [],
#  [],
#  ['5075'],
#  ['5000'],
#  ['5010'],
#  ['5000'],
#  [],
# ...

# %%
data_NaN["Suburb Address"] = suburb

# %%
data_NaN.head()
# Out:
#              Name                              Address Sale Type  Total Money  \
# 0      Phoebe Dao                      267 Hutt street  Delivery         21.8
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033  Delivery          0.0
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  Delivery         19.7
# 5           Nancy                Unit5/77 cowan street   Pick-up          0.0
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012  Delivery          0.0
#
#      Shipper     Status   Payment Type      Time   Shop Suburb Type Shop  \
# 0   Minh Tan  Completed  Bank Transfer  20:27:38           CBD    BimBim
# 1  Hoang Anh  Cancelled  Bank Transfer  07:06:46           CBD    BimBim
# 4  Hoang Anh  Completed  Bank Transfer  21:40:09  West Croydon    BimBim
# 5  Hoang Anh  Cancelled  Bank Transfer  04:30:00    Athol Park    BimBim
# 6  Hoang Anh  Cancelled  Bank Transfer  18:00:00    Athol Park    BimBim
#
#   Suburb Address
# 0             []
# 1         [5033]
# ...

# %%
data_NaN["Date"] = data["Date"] + "/" + data["Month"] + "/" + data["Year"]

# %%
data.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                            Time Sale Sale Type  Total Money  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery        21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery         0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up        18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up        15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery        19.70
#
# ...

# %%
data_NaN.head()
# Out:
#              Name                              Address Sale Type  Total Money  \
# 0      Phoebe Dao                      267 Hutt street  Delivery         21.8
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033  Delivery          0.0
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  Delivery         19.7
# 5           Nancy                Unit5/77 cowan street   Pick-up          0.0
# 6       Hari Đoàn  227 hanson road, athol park Sa 5012  Delivery          0.0
#
#      Shipper     Status   Payment Type      Time   Shop Suburb Type Shop  \
# 0   Minh Tan  Completed  Bank Transfer  20:27:38           CBD    BimBim
# 1  Hoang Anh  Cancelled  Bank Transfer  07:06:46           CBD    BimBim
# 4  Hoang Anh  Completed  Bank Transfer  21:40:09  West Croydon    BimBim
# 5  Hoang Anh  Cancelled  Bank Transfer  04:30:00    Athol Park    BimBim
# 6  Hoang Anh  Cancelled  Bank Transfer  18:00:00    Athol Park    BimBim
#
#   Suburb Address         Date
# ...

# %%
cancel_Sell = data_NaN.loc[data_NaN["Status"] == "Cancelled"]
cancel_Sell.reset_index()
# Out:
#     index               Name                                      Address  \
# 0       1     Tran Huy Thong             90 Bagot Avenue, Cowandilla 5033
# 1       5              Nancy                        Unit5/77 cowan street
# 2       6          Hari Đoàn          227 hanson road, athol park Sa 5012
# 3      10      Nicole Nguyen             163 Days Road, Regency Park,SA,
# 4      13          GIANG BUI        46 Hampstead Road, Broadview 5083 SA
# 5      16        Lien nguyen           70 hooking tce- woodville garrdend
# 6      19              Hồ Vy                Eynesbury college Franklin St
# 7      20              Hồ Vy                Eynesbury college Franklin st
# 8      23         Duyen Tran                           5 Balranald Street
# 9      27                 Vy               518 Prospect Road Kilburn 5082
# 10     28                 Vy              518 Prospect Road killburn 5082
# 11     29                 Vy              518 Prospect Road killburn 5082
# ...

# %%
complete_Sell = data_NaN.loc[data_NaN["Status"] == "Completed"]
complete_Sell.reset_index()
# Out:
#      index           Name                                     Address  \
# 0        0     Phoebe Dao                             267 Hutt street
# 1        4        Phuong          54 Hallet Bvld Allenby Gardens 5009
# 2        7     Thanh Pham            9 Booker Ct, Pennington, SA 5013
# 3       11  Nicole Nguyen                               163 Days Road
# 4       12          Duyên                               Ferryden park
# ..     ...            ...                                         ...
# 104    156        Gia Bảo                 4a jaffrey st , Blair Athol
# 105    157      Kim Linh            19D Gameau Road Paradise SA 5075
# 106    159  Quế Minh Trần            10 Warner Avenue, Findon SA 5023
# 107    161          Heidi  Unit 26/131 Gray street, Adelaide, SA 5000
# 108    162            Han              64 Overland Road, Croydon Park
#
#     Sale Type  Total Money    Shipper     Status   Payment Type      Time  \
# ...

# %%
complete_Sell.to_csv("Complete_Sell.csv",index = False)
cancel_Sell.to_csv("Cancel_Sell.csv", index = False)

# %%
complete_Sell = complete_Sell.drop(["Address"],axis=1)
cancel_Sell = cancel_Sell.drop(["Address"],axis=1)

# %%
complete_Sell = complete_Sell.drop(["Suburb Address"],axis=1)
cancel_Sell = cancel_Sell.drop(["Suburb Address"],axis=1)

# %%
cancel_Sell.head()
# Out:
#               Name Sale Type  Total Money    Shipper     Status  \
# 1   Tran Huy Thong  Delivery          0.0  Hoang Anh  Cancelled
# 5            Nancy   Pick-up          0.0  Hoang Anh  Cancelled
# 6        Hari Đoàn  Delivery          0.0  Hoang Anh  Cancelled
# 10   Nicole Nguyen   Pick-up          0.0   Minh Tan  Cancelled
# 13       GIANG BUI  Delivery          0.0   Minh Tan  Cancelled
#
#      Payment Type      Time   Shop Suburb Type Shop         Date
# 1   Bank Transfer  07:06:46           CBD    BimBim  21/Feb/2020
# 5   Bank Transfer  04:30:00    Athol Park    BimBim  21/Feb/2020
# 6   Bank Transfer  18:00:00    Athol Park    BimBim  23/Feb/2020
# 10  Bank Transfer  19:33:40  Croydon Park    BimBim  23/Feb/2020
# 13  Bank Transfer  14:58:54     Woodville    BimBim  27/Feb/2020

# %%
complete_Sell.head()
# Out:
#              Name Sale Type  Total Money    Shipper     Status   Payment Type  \
# 0      Phoebe Dao  Delivery        21.80   Minh Tan  Completed  Bank Transfer
# 4         Phuong   Delivery        19.70  Hoang Anh  Completed  Bank Transfer
# 7      Thanh Pham  Delivery        31.70   Minh Tan  Completed  Bank Transfer
# 11  Nicole Nguyen  Delivery        32.60   Minh Tan  Completed  Bank Transfer
# 12          Duyên   Pick-up        16.85  Hoang Anh  Completed  Bank Transfer
#
#         Time   Shop Suburb Type Shop         Date
# 0   20:27:38           CBD    BimBim  20/Feb/2020
# 4   21:40:09  West Croydon    BimBim  21/Feb/2020
# 7   18:59:08    Athol Park    BimBim  21/Feb/2020
# 11  20:30:00  Croydon Park    BimBim  23/Feb/2020
# 12  14:01:20  West Croydon    BimBim  27/Feb/2020

# %%
data.head()
# Out:
#              Name                              Address            Shop Name  \
# 0      Phoebe Dao                      267 Hutt street           BimBim-CBD
# 1  Tran Huy Thong     90 Bagot Avenue, Cowandilla 5033           BimBim-CBD
# 2  Tran Huy Thong                                  NaN  BimBim-Croydon Park
# 3           Annie                                  NaN    BimBim-Athol Park
# 4         Phuong   54 Hallet Bvld Allenby Gardens 5009  BimBim-West Croydon
#
#                                            Time Sale Sale Type  Total Money  \
# 0  Thu Feb 20 2020 20:27:38 GMT+1030 (Australian ...  Delivery        21.80
# 1  Fri Feb 21 2020 07:06:46 GMT+0800 (Singapore S...  Delivery         0.00
# 2  Fri Feb 21 2020 15:00:47 GMT+0800 (Singapore S...   Pick-up        18.80
# 3           Fri Feb 21 2020 07:00:50 GMT+1030 (ACDT)   Pick-up        15.85
# 4           Fri Feb 21 2020 21:40:09 GMT+1030 (ACDT)  Delivery        19.70
#
# ...

# %%
complete_Sell["index"] = range(len(complete_Sell))

# %%
complete_Sell.head()
# Out:
#              Name Sale Type  Total Money    Shipper     Status   Payment Type  \
# 0      Phoebe Dao  Delivery        21.80   Minh Tan  Completed  Bank Transfer
# 4         Phuong   Delivery        19.70  Hoang Anh  Completed  Bank Transfer
# 7      Thanh Pham  Delivery        31.70   Minh Tan  Completed  Bank Transfer
# 11  Nicole Nguyen  Delivery        32.60   Minh Tan  Completed  Bank Transfer
# 12          Duyên   Pick-up        16.85  Hoang Anh  Completed  Bank Transfer
#
#         Time   Shop Suburb Type Shop         Date  index
# 0   20:27:38           CBD    BimBim  20/Feb/2020      0
# 4   21:40:09  West Croydon    BimBim  21/Feb/2020      1
# 7   18:59:08    Athol Park    BimBim  21/Feb/2020      2
# 11  20:30:00  Croydon Park    BimBim  23/Feb/2020      3
# 12  14:01:20  West Croydon    BimBim  27/Feb/2020      4

# %%
cancel_Sell["index"] = range(len(cancel_Sell))

# %%
complete_Sell.to_csv("Complete_Sell.csv",index = False)
cancel_Sell.to_csv("Cancel_Sell.csv", index = False)
